# %% [markdown]
# # Lab 1b. Plotting and Visualization
#
# Probability and Statistics, Spring 2017
# CC BY-NC-SA, Sakari Lukkarinen
# Helsinki Metropolia University of Applied Sciences
#
# Readings: Johansson. (2015). [Numerical Python: A Practical Techniques Approach For Industry.](https://metropolia.finna.fi/Record/nelli15.3710000000486209)

# %% [markdown]
# ## Chapter 4. Plotting and Visualization

# %% [markdown]
# Import the matplotlib modules and configure the Notebook to show the `inline` backend.

# %%
import numpy as np
# %pylab inline

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Create an `x`-array having values from 0 to 6 (stepsize = 0.1) and use that to calculate the values for $y = (x-3)^2 - 10$. Make a plot of that function and annotate the graphics with labels and title.

# %%
x = arange(0,6.1,.1)
y = (x-3)**2-10
plot(x,y)
grid()
xlabel('x axis')
ylabel('y axis')
title('$y = (x-3)^2-10$')

# %% [markdown]
# Use the same data to create the following 2D graphs:
#
# a) a step-like graph
# b) a bar graph
# c) a scatterogram
# d) an area filled between the function and the x-axis

# %%
step(x, y)
grid()

# %%
bar(x, y)
grid()

# %%
scatter(x,y)
grid()

# %%
fill(x, y)
grid()

# %% [markdown]
# Use the same data but make a plot, but now use
#
# a) linewidth of 3
# b) dashed line type
# c) squared markers having size of 12 and color of red

# %%
plot(x, y, linewidth=3)
grid()

# %%
plot(x, y, '--')
grid()

# %%
plot(x, y, 'rs', markersize=12)
grid()

# %% [markdown]
# Plot in the same graph the following approximations of log(x):
#
# $f_1(x) = (x-1)$
# $f_2(x) = (x-1) - \frac{1}{2}(x-1)^2$
# $f_3(x) = (x-1) - \frac{1}{2}(x-1)^2 + \frac{1}{3}(x-1)^3$
# $f_4(x) = (x-1) - \frac{1}{2}(x-1)^2 + \frac{1}{3}(x-1)^3 - \frac{1}{4}(x-1)^4$
#
# Use the range $x \in [0, 2]$ with suitable stepsize. Add legends to the graphs to explain what the graphs are.

# %%
x = arange(0,2.1,.01)
y1 = x-1
logx = log(x)
plot(logx,y1,label='$y=x-1$')
grid()
legend(loc='upper left')
# Out:
# C:\Users\Chanh Nguyen\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %%
y2 = x-1-1/2*(x-1)**2
plot(logx, y2, label='$y=(x-1)-1/2(x-1)^2$')
grid()
legend(loc='upper left')

# %%
y3 = x-1-1/2*(x-1)**2+1/3*(x-1)**3
plot(logx, y3, label='$y=(x-1)-1/2(x-1)^2+1/3(x-1)^3$')
grid()
legend(loc='upper left')

# %%
y4 = x-1-1/2*(x-1)**2+1/3*(x-1)**3-1/4*(x-1)**4
plot(logx, y4, label='$y=(x-1)-1/2(x-1)^2+1/3(x-1)^3-1/4(x-1)^4$')
grid()
legend(loc='upper left')

# %% [markdown]
# Create an array of evenly distributed random numbers ([`random.rand`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.rand.html)) of length 100 samples. Make a graph of the values. Limit the axes to show only the samples with index from 50 to 70. Add gridlines to the graph.

# %%
x = arange(0, 100)
y = random.rand(100)
plot(x, y)
xlim(50, 70)
grid()

# %% [markdown]
# Create two arrays ($x_1$ and $x_2$) of normally distributed random numbers ([`random.randn`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html)) both having 100 samples. Create a 2x2 subplots and show in them:
#
# a) in upper left corner: [`scatter(x1, x2)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)
# b) in upper right corner: [`hist(x1)`](http://matplotlib.org/api/pyplot_api.html?highlight=hist#matplotlib.pyplot.hist)
# c) in lower left corner: `hist(x2)`
# d) in lower right corner: `scatter(3*x1 + x2)`

# %%
x1 = random.rand(100)
x2 = random.rand(100)
plot.subplot(x1, x2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-7c610f6f7016> in <module>()
#       1 x1 = random.rand(100)
#       2 x2 = random.rand(100)
# ----> 3 plot.subplot(x1, x2)
#
# AttributeError: 'function' object has no attribute 'subplot'

# %% [markdown]
# Create an array of normally distributed random numbers having a length of 10000. Make a histogram of the values. Count how many percent of the values are between -1.0 and 1.0 and show that value in the title of the graph.

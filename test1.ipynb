# %%
4+5
# Out:
# 9

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import *
from numpy import *

# %%
plt.plot([4,63,1,3,55,1])
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
rN = np.arange(0.0, 5.0, 0.2)

# red dashes, blue squares and green triangles
plt.plot(rN, rN, 'r--', rN, rN**2, 'bs', rN, rN**3, 'g^')
plt.show()
